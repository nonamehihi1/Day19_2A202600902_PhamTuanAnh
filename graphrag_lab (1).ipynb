# %% [markdown]
# # Lab Day 19 — Building a GraphRAG System
#
# **Goal:** build a full **GraphRAG** pipeline from a raw text corpus and compare it
# against a plain **Flat RAG** baseline.
#
# This notebook walks through the lab end-to-end:
#
# 1. **Entity & Relation Extraction** — turn unstructured text into `(subject, relation, object)` triples with an LLM or **[LangExtract](https://github.com/google/langextract)** (few-shot, source-grounded extraction).
# 2. **Graph Construction** — deduplicate entities and build a knowledge graph (**NetworkX**, optionally mirrored to **Neo4j**).
# 3. **Indexing** — embed chunks into a vector index for retrieval.
# 4. **GraphRAG Querying** — link a question to graph entities, traverse a **multi-hop** subgraph, and answer from graph facts + supporting text.
# 5. **Flat RAG vs GraphRAG** — run the same questions through both and compare.
#
# > **Runs offline by default** using **Ollama** + **NetworkX** (no API key, no database).
# > Switch to **OpenAI** and/or **Neo4j** by changing the single `CONFIG` cell below.

# %% [markdown]
# ## Part 0 — Setup & Configuration
#
# **Before running:**
#
# - *Offline path (default):* install [Ollama](https://ollama.com), then in a terminal:
#   ```
#   ollama serve
#   ollama pull llama3.1
#   ollama pull nomic-embed-text
#   ```
# - *OpenAI path:* set `LLM_PROVIDER = "openai"` in CONFIG and export `OPENAI_API_KEY`.
# - *LangExtract path (recommended):* set `EXTRACTION_BACKEND = "langextract"` in CONFIG — works with Ollama (offline) or OpenAI; uses few-shot examples for more consistent triples.
# - *Neo4j (optional):* set `GRAPH_BACKEND = "neo4j"` and fill the Neo4j credentials.

# %%
# %pip install -q networkx numpy pandas matplotlib requests tqdm google-generativeai neo4j langextract openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.4 MB/s eta 0:00:00

# %%
# !sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve > /dev/null 2>&1 &
import time
time.sleep(3)
# !ollama pull llama3.1
# !ollama pull nomic-embed-text
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 53 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (9,184 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import os, re, json, glob, difflib, collections
import numpy as np
import pandas as pd
import requests
import networkx as nx
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# %%
# ====================== CONFIG ======================
LLM_PROVIDER       = "openai"        # We use openai provider to connect to GLM
GRAPH_BACKEND      = "networkx"      # "networkx" | "neo4j"
EXTRACTION_BACKEND = "prompt"   # "langextract" | "prompt"

# --- GLM (via OpenAI SDK) ---
OPENAI_MODEL       = "glm-4-plus"
OPENAI_EMBED_MODEL = "embedding-3"

# --- Data / runtime ---
DATASET_DIR   = "dataset"
MAX_DOCS      = 12
CHUNK_SIZE    = 1200
CHUNK_OVERLAP = 150

print(f"LLM_PROVIDER={LLM_PROVIDER} | EXTRACTION_BACKEND={EXTRACTION_BACKEND} | GRAPH_BACKEND={GRAPH_BACKEND}")
# Out:
# LLM_PROVIDER=openai | EXTRACTION_BACKEND=prompt | GRAPH_BACKEND=networkx

# %%
import os

os.environ['OPENAI_API_KEY'] = 'bdf9201464184cc3a9567110cdeb8c56.MlPHakhaq9ztxokv'
os.environ['OPENAI_BASE_URL'] = 'https://open.bigmodel.cn/api/paas/v4/'

# ====================== CONFIG ======================
LLM_PROVIDER       = "openai"
GRAPH_BACKEND      = "networkx"
EXTRACTION_BACKEND = "prompt"

# --- GLM Models ---
OPENAI_MODEL       = "glm-4-plus"
OPENAI_EMBED_MODEL = "embedding-3"

# --- Thêm lại cấu hình Ollama để băm Vector ---
OLLAMA_HOST        = "http://localhost:11434"
OLLAMA_EMBED_MODEL = "nomic-embed-text"

# --- Data / runtime ---
DATASET_DIR   = "dataset"
MAX_DOCS      = 12
CHUNK_SIZE    = 1200
CHUNK_OVERLAP = 150

print(f"LLM_PROVIDER={LLM_PROVIDER} | EXTRACTION_BACKEND={EXTRACTION_BACKEND} | GRAPH_BACKEND={GRAPH_BACKEND}")
# Out:
# LLM_PROVIDER=openai | EXTRACTION_BACKEND=prompt | GRAPH_BACKEND=networkx

# %%
# ---- Provider-agnostic LLM + embedding wrappers ----
import google.generativeai as genai
from google.colab import userdata

def llm_complete(prompt, system=None, temperature=0.0, max_tokens=1200):
    if LLM_PROVIDER == "gemini":
        genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))
        model = genai.GenerativeModel(
            model_name=GEMINI_MODEL,
            system_instruction=system
        )
        resp = model.generate_content(
            prompt,
            generation_config=genai.types.GenerationConfig(
                temperature=temperature,
                max_output_tokens=max_tokens
            )
        )
        return resp.text

    elif LLM_PROVIDER == "openai":
        from openai import OpenAI
        client = OpenAI()
        messages = []
        if system: messages.append({"role": "system", "content": system})
        messages.append({"role": "user", "content": prompt})
        resp = client.chat.completions.create(
            model=OPENAI_MODEL, messages=messages,
            temperature=temperature, max_tokens=max_tokens)
        return resp.choices[0].message.content

    elif LLM_PROVIDER == "ollama":
        payload = {"model": OLLAMA_MODEL, "prompt": prompt, "stream": False,
                   "options": {"temperature": temperature, "num_predict": max_tokens}}
        if system: payload["system"] = system
        r = requests.post(OLLAMA_HOST + "/api/generate", json=payload, timeout=600)
        r.raise_for_status()
        return r.json()["response"]
    raise ValueError("Unknown LLM_PROVIDER: " + LLM_PROVIDER)

def embed(texts):
    if isinstance(texts, str):
        texts = [texts]

    if LLM_PROVIDER == "gemini":
        genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))
        result = genai.embed_content(model=GEMINI_EMBED_MODEL, content=texts, task_type="retrieval_document")
        return [np.array(e, dtype=float) for e in result['embedding']]

    if LLM_PROVIDER == "openai":
        # Bỏ qua gọi API của GLM cho bước tạo Vector vì API Key này không hỗ trợ.
        # Hàm sẽ tự động chạy xuống phần code dùng Ollama ở phía dưới.
        pass


    out = []
    for t in texts:
        r = requests.post(OLLAMA_HOST + "/api/embeddings",
                          json={"model": OLLAMA_EMBED_MODEL, "prompt": t}, timeout=600)
        r.raise_for_status()
        out.append(np.array(r.json()["embedding"], dtype=float))
    return out

# %%
# Smoke test — verifies the chosen provider responds (safe to re-run).
try:
    print("LLM says:", llm_complete("Reply with exactly: OK", max_tokens=10).strip()[:50])
    print("Embedding dim:", len(embed("hello world")[0]))
except Exception as e:
    print("Provider not reachable yet:", e)
    print("Ollama:  run `ollama serve` and pull `llama3.1` + `nomic-embed-text`.")
    print("OpenAI:  set LLM_PROVIDER='openai' and export OPENAI_API_KEY.")
# Out:
# LLM says: OK
# Provider not reachable yet: name 'OLLAMA_HOST' is not defined
# Ollama:  run `ollama serve` and pull `llama3.1` + `nomic-embed-text`.
# OpenAI:  set LLM_PROVIDER='openai' and export OPENAI_API_KEY.

# %% [markdown]
# ## Part 1 — Concepts (the lab's research questions)
#
# **1. Entity Extraction — how does the LLM tell an *entity* from an *attribute*?**
# We extract structured triples `(subject, relation, object)` with entity *types*.
# By default we use **[LangExtract](https://github.com/google/langextract)** — few-shot examples
# teach the schema, and each extraction can be traced back to its source span. The `prompt`
# backend is a simpler single-shot JSON alternative. Entities become *nodes*; relationships become *edges*.
#
# **2. Graph Construction — why does deduplication matter?**
# The same real-world entity appears under many surface forms ("Tesla", "Tesla Inc.", "tesla").
# If we don't merge them, the graph fragments: facts about one entity scatter across several nodes,
# breaking traversal. We normalize names and fuzzy-merge near-duplicates into a single canonical node.
#
# **3. Query Answering — graph traversal vs. plain vector search?**
# *Flat RAG* embeds the query and returns the top-k most *similar* chunks — great for "what does the text say
# about X", but blind to relationships that aren't co-located in one passage.
# *GraphRAG* links the query to entities and **traverses** the graph (multi-hop) to assemble connected facts —
# so it can answer "how is A connected to C *through* B" even when no single chunk states it.

# %% [markdown]
# ## Part 2 — Load & Chunk the Corpus
#
# We read the `*.txt` files from `DATASET_DIR` and split each into overlapping character chunks.

# %%
# !unzip -q -o /content/dataset.zip -d /content/
DATASET_DIR = "/content/dataset"

def load_documents(directory, max_docs=None):
    paths = sorted(glob.glob(os.path.join(directory, "*.txt")))
    if max_docs:
        paths = paths[:max_docs]
    docs = []
    for p in paths:
        with open(p, "r", encoding="utf-8", errors="ignore") as f:
            docs.append({"doc_id": os.path.basename(p), "text": f.read()})
    return docs

def chunk_text(text, size, overlap):
    text = text.strip()
    chunks, start = [], 0
    while start < len(text):
        end = start + size
        chunks.append(text[start:end])
        if end >= len(text):
            break
        start = max(0, end - overlap)
    return chunks


documents = load_documents(DATASET_DIR, MAX_DOCS)
chunks = []
for d in documents:
    for j, ctext in enumerate(chunk_text(d["text"], CHUNK_SIZE, CHUNK_OVERLAP)):
        chunks.append({"chunk_id": f"{d['doc_id']}::ch{j}",
                       "doc_id": d["doc_id"], "text": ctext})

print(f"Loaded {len(documents)} docs -> {len(chunks)} chunks")
print("\nExample chunk:\n", chunks[0]["text"][:300])
# Out:
# Loaded 12 docs -> 211 chunks
#
# Example chunk:
#  Query: US electric vehicle sector sentiment analysis
# Title: Evaluating electric vehicle market growth across U.S. cities ...
# Link: https://theicct.org/publication/evaluating-electric-vehicle-market-growth-across-u-s-cities/
# Snippet: Sep 14, 2021 ... This study, an update of our previous analysis of

# %% [markdown]
# ## Part 3 — Entity & Relation Extraction
#
# Two backends (set `EXTRACTION_BACKEND` in CONFIG):
#
# | Backend | How it works | Best for |
# |---------|--------------|----------|
# | **`langextract`** (default) | Google's [LangExtract](https://github.com/google/langextract) library — few-shot examples, schema-guided output, source grounding | More consistent triples; same Ollama/OpenAI provider as the rest of the lab |
# | **`prompt`** | Single-shot JSON prompt to the LLM | Minimal dependencies; quick baseline |
#
# Both produce the same `(subject, relation, object)` triple list consumed by graph construction below.

# %%
import textwrap
import langextract as lx

# ... (parse_json_triples and extract_triples_prompt stay the same) ...
def parse_json_triples(raw):
    if not raw: return []
    text = raw.strip()
    text = re.sub(r"^```[a-zA-Z]*", "", text).strip().strip("`").strip()
    try:
        data = json.loads(text)
    except Exception:
        m = re.search(r"\{.*\}", text, re.DOTALL)
        if not m: return []
        try: data = json.loads(m.group(0))
        except Exception: return []
    return data.get("triples", []) if isinstance(data, dict) else []

EXTRACT_SYSTEM = "You are an information-extraction engine that builds knowledge graphs from text."

def extract_triples_prompt(text):
    prompt = (
        "Extract the key ENTITIES and RELATIONSHIPS from the text below.\n"
        "Return ONLY valid JSON in this exact shape (no prose, no markdown):\n"
        '{"triples": [{"subject": "", "subject_type": "", "relation": "", "object": "", "object_type": ""}]}\n\n'
        "Guidelines:\n"
        "- subject/object must be specific named entities (company, sector, technology, product, place, person, metric).\n"
        "- relation is a short snake_case verb phrase: operates_in, invests_in, competes_with, located_in, produces, reported.\n"
        "- Use canonical, concise entity names. Skip vague pronouns.\n"
        "- Return at most 15 of the most important triples.\n\n"
        "Text:\n<<<\n" + text[:3500] + "\n>>>"
    )
    raw = llm_complete(prompt, system=EXTRACT_SYSTEM, max_tokens=1200)
    return parse_json_triples(raw)

# Updated model kwargs for LangExtract to support Gemini
def _langextract_model_kwargs():
    if LLM_PROVIDER == "ollama":
        return {"model_id": OLLAMA_MODEL, "model_url": OLLAMA_HOST}
    if LLM_PROVIDER == "openai":
        return {"model_id": OPENAI_MODEL}
    if LLM_PROVIDER == "gemini":
        return {"model_id": GEMINI_MODEL, "api_key": userdata.get('GOOGLE_API_KEY')}
    raise ValueError("Unknown LLM_PROVIDER: " + LLM_PROVIDER)

# ... (Rest of extraction functions remain the same) ...
def lx_extractions_to_triples(result):
    triples = []
    for ext in (result.extractions or []):
        if ext.extraction_class != "relationship": continue
        attrs = ext.attributes or {}
        s, o, r = attrs.get("subject"), attrs.get("object"), attrs.get("relation")
        if not (s and o and r): continue
        triples.append({
            "subject": str(s).strip(), "subject_type": str(attrs.get("subject_type", "")).strip(),
            "relation": str(r).strip(), "object": str(o).strip(),
            "object_type": str(attrs.get("object_type", "")).strip(),
        })
    return triples

def extract_triples_langextract(text):
    result = lx.extract(
        text_or_documents=text[:3500],
        prompt_description=LX_PROMPT,
        examples=LX_EXAMPLES,
        max_char_buffer=min(CHUNK_SIZE, 1200),
        **_langextract_model_kwargs(),
    )
    return lx_extractions_to_triples(result)

def extract_triples(text):
    if EXTRACTION_BACKEND == "langextract": return extract_triples_langextract(text)
    if EXTRACTION_BACKEND == "prompt": return extract_triples_prompt(text)
    raise ValueError("Unknown EXTRACTION_BACKEND: " + EXTRACTION_BACKEND)

# %%
# Run extraction across all chunks (limited by MAX_DOCS). This is the slow step.
all_triples = []   # each: chunk_id, doc_id, subject, subject_type, relation, object, object_type

for ch in tqdm(chunks, desc=f"Extracting ({EXTRACTION_BACKEND})"):
    try:
        triples = extract_triples(ch["text"])
    except Exception:
        triples = []
    for t in triples:
        if not (t.get("subject") and t.get("object") and t.get("relation")):
            continue
        all_triples.append({
            "chunk_id": ch["chunk_id"], "doc_id": ch["doc_id"],
            "subject": str(t["subject"]).strip(),
            "subject_type": str(t.get("subject_type", "")).strip(),
            "relation": str(t["relation"]).strip(),
            "object": str(t["object"]).strip(),
            "object_type": str(t.get("object_type", "")).strip(),
        })

print(f"Extracted {len(all_triples)} raw triples from {len(chunks)} chunks")
# Out:
# Extracting (prompt):   0%|          | 0/211 [00:00<?, ?it/s]
# Extracted 2536 raw triples from 211 chunks

# %%
pd.DataFrame(all_triples).head(15)
# Out:
#           chunk_id     doc_id  \
# 0   doc_1.txt::ch0  doc_1.txt
# 1   doc_1.txt::ch0  doc_1.txt
# 2   doc_1.txt::ch0  doc_1.txt
# 3   doc_1.txt::ch0  doc_1.txt
# 4   doc_1.txt::ch0  doc_1.txt
# 5   doc_1.txt::ch0  doc_1.txt
# 6   doc_1.txt::ch0  doc_1.txt
# 7   doc_1.txt::ch0  doc_1.txt
# 8   doc_1.txt::ch0  doc_1.txt
# 9   doc_1.txt::ch0  doc_1.txt
# 10  doc_1.txt::ch0  doc_1.txt
# 11  doc_1.txt::ch0  doc_1.txt
# 12  doc_1.txt::ch0  doc_1.txt
# 13  doc_1.txt::ch0  doc_1.txt
# 14  doc_1.txt::ch0  doc_1.txt
#
#                                               subject  subject_type  \
# 0                                       United States         place
# 1                             electric vehicle market        sector
# 2                             electric vehicle market        sector
# 3                             electric vehicle market        sector
# 4                             electric vehicle market        sector
# 5                                              states         place
# 6                                              cities         place
# 7                                         regulations        policy
# 8                                              states         place
# 9                                   local governments  organization
# 10                                  utility companies  organization
# 11                                             states         place
# 12                                             cities         place
# 13                          zero-emission regulations        policy
# 14  The International Council on Clean Transportation  organization
#
#             relation                                    object object_type
# 0                has                   electric vehicle market      sector
# 1          grew_from                     few thousand vehicles      metric
# 2            grew_to            315,000 vehicles sold annually      metric
# 3                had                       2.4% electric share      metric
# 4                had                         2% electric share      metric
# 5               have                 strongest policy supports      policy
# 6               have                 strongest policy supports      policy
# 7            require       electric vehicle model availability  technology
# 8            promote                         electric vehicles  technology
# 9            promote                         electric vehicles  technology
# 10           promote                         electric vehicles  technology
# 11              have  greatest electric vehicle market success      metric
# 12              have  greatest electric vehicle market success      metric
# 13  are_essential_to                             market growth      metric
# 14         published                                     study    document

# %% [markdown]
# ### (Optional) LangExtract source-grounding visualization
#
# When `EXTRACTION_BACKEND == "langextract"`, re-run extraction on one chunk and generate
# an interactive HTML map of extractions back to source text spans.

# %%
if EXTRACTION_BACKEND == "langextract":
    demo_text = chunks[0]["text"][:2500]
    lx_result = lx.extract(
        text_or_documents=demo_text,
        prompt_description=LX_PROMPT,
        examples=LX_EXAMPLES,
        max_char_buffer=min(CHUNK_SIZE, 1200),
        **_langextract_model_kwargs(),
    )
    lx.io.save_annotated_documents([lx_result], output_name="lx_demo.jsonl", output_dir=".")
    html = lx.visualize("lx_demo.jsonl")
    html_path = "lx_extraction_viz.html"
    with open(html_path, "w", encoding="utf-8") as f:
        f.write(html.data if hasattr(html, "data") else html)
    print(f"Saved interactive visualization -> {html_path}")
    print(f"Grounded extractions: {sum(1 for e in lx_result.extractions if e.char_interval)} / {len(lx_result.extractions)}")
else:
    print("Set EXTRACTION_BACKEND='langextract' to generate the HTML visualization.")
# Out:
# Set EXTRACTION_BACKEND='langextract' to generate the HTML visualization.

# %% [markdown]
# ## Part 4 — Graph Construction (with Deduplication)
#
# We normalize entity names and fuzzy-merge near-duplicates into canonical nodes,
# then build a directed multigraph in **NetworkX**. Each edge remembers which chunk it came from
# (provenance), so GraphRAG can pull the supporting text later.

# %%
def normalize(name):
    n = re.sub(r"\s+", " ", str(name)).strip()
    return n.strip(' .,:;"\'')

# Build a canonical alias map by fuzzy-merging surface forms.
raw_entities = sorted({normalize(t[k]) for t in all_triples for k in ("subject", "object")} - {""})

canonical, canon_list = {}, []
for e in raw_entities:
    match = difflib.get_close_matches(e.lower(), [c.lower() for c in canon_list], n=1, cutoff=0.92)
    if match:
        canonical[e] = next(c for c in canon_list if c.lower() == match[0])
    else:
        canon_list.append(e)
        canonical[e] = e

def canon(name):
    return canonical.get(normalize(name), normalize(name))

print(f"{len(raw_entities)} surface entities -> {len(canon_list)} canonical entities after dedup")
# Out:
# 2311 surface entities -> 2144 canonical entities after dedup

# %%
G = nx.MultiDiGraph()
entity_chunks = {}   # canonical entity -> set of chunk_ids (provenance)
entity_type = {}

for t in all_triples:
    s, o = canon(t["subject"]), canon(t["object"])
    if not s or not o:
        continue
    if t["subject_type"]:
        entity_type.setdefault(s, t["subject_type"])
    if t["object_type"]:
        entity_type.setdefault(o, t["object_type"])
    G.add_node(s, type=entity_type.get(s, ""))
    G.add_node(o, type=entity_type.get(o, ""))
    G.add_edge(s, o, relation=t["relation"], chunk_id=t["chunk_id"], doc_id=t["doc_id"])
    entity_chunks.setdefault(s, set()).add(t["chunk_id"])
    entity_chunks.setdefault(o, set()).add(t["chunk_id"])

print(f"Graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
# Out:
# Graph: 2144 nodes, 2536 edges

# %%
print("Top entities by degree:")
for n, d in sorted(G.degree, key=lambda x: x[1], reverse=True)[:15]:
    print(f"  {d:3d}  {n}  ({G.nodes[n].get('type','')})")
# Out:
# Top entities by degree:
#   440  Polestar  (company)
#   155  REE  (company)
#   106  VinFast  (company)
#   100  NVIDIA  (company)
#    70  ZEEKR  (company)
#    68  Electric vehicles  (technology)
#    66  Polestar Automotive Holding UK PLC  (company)
#    61  ZEEKR INC  (company)
#    55  Company  (company)
#    45  China  (place)
#    38  Mercedes-Benz  (company)
#    32  Tesla  (company)
#    28  Mercedes-Benz Vans  (company)
#    28  Mercedes-Benz Mobility  (company)
#    27  BYD  (company)

# %%
# Visualize the most-connected slice of the graph
top_nodes = [n for n, _ in sorted(G.degree, key=lambda x: x[1], reverse=True)[:25]]
H = G.subgraph(top_nodes)

plt.figure(figsize=(13, 9))
pos = nx.spring_layout(H, k=0.6, seed=42)
nx.draw_networkx_nodes(H, pos, node_size=900, node_color="#9ecae1")
nx.draw_networkx_labels(H, pos, font_size=8)
nx.draw_networkx_edges(H, pos, alpha=0.3, arrows=True)
nx.draw_networkx_edge_labels(
    H, pos, font_size=6,
    edge_labels={(u, v): d["relation"] for u, v, d in H.edges(data=True)})
plt.title("Knowledge Graph — top 25 entities by degree")
plt.axis("off"); plt.tight_layout(); plt.show()

# %% [markdown]
# ### (Optional) Mirror the graph into Neo4j
#
# Runs only when `GRAPH_BACKEND == "neo4j"` and credentials are set — otherwise it is skipped,
# so the notebook still runs fully offline.

# %%
if GRAPH_BACKEND == "neo4j":
    from neo4j import GraphDatabase
    driver = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USER, NEO4J_PASSWORD))
    with driver.session() as session:
        session.run("MATCH (n) DETACH DELETE n")
        for n, data in G.nodes(data=True):
            session.run("MERGE (e:Entity {name:$name}) SET e.type=$type",
                        name=n, type=data.get("type", ""))
        for u, v, data in G.edges(data=True):
            session.run(
                "MATCH (a:Entity {name:$u}), (b:Entity {name:$v}) "
                "MERGE (a)-[r:REL {type:$rel}]->(b) SET r.doc_id=$doc",
                u=u, v=v, rel=data.get("relation", ""), doc=data.get("doc_id", ""))
    driver.close()
    print("Pushed graph to Neo4j at", NEO4J_URL)
else:
    print("GRAPH_BACKEND != 'neo4j' -> skipping. Set GRAPH_BACKEND='neo4j' + creds in CONFIG to enable.")
# Out:
# GRAPH_BACKEND != 'neo4j' -> skipping. Set GRAPH_BACKEND='neo4j' + creds in CONFIG to enable.

# %% [markdown]
# **Multi-hop traversal in Cypher** (run in the Neo4j Browser once the graph is loaded):
#
# ```cypher
# // 2-hop neighbourhood around an entity
# MATCH path = (a:Entity {name: "Tesla"})-[*1..2]-(b:Entity)
# RETURN path LIMIT 50;
# ```

# %% [markdown]
# ## Part 5 — Vector Index (for the Flat RAG baseline)
#
# A minimal cosine-similarity index over the chunk embeddings — this is what plain RAG retrieves from.

# %%
class VectorIndex:
    def __init__(self):
        self.ids, self.meta, self.matrix = [], {}, None

    def build(self, items):
        vecs = []
        for it in tqdm(items, desc="Embedding"):
            vecs.append(embed(it["text"])[0])
            self.ids.append(it["chunk_id"])
            self.meta[it["chunk_id"]] = it
        m = np.vstack(vecs)
        self.matrix = m / (np.linalg.norm(m, axis=1, keepdims=True) + 1e-9)

    def search(self, query, k=4):
        q = embed(query)[0]
        q = q / (np.linalg.norm(q) + 1e-9)
        sims = self.matrix @ q
        order = np.argsort(-sims)[:k]
        return [(self.ids[i], float(sims[i]), self.meta[self.ids[i]]) for i in order]

vindex = VectorIndex()
vindex.build(chunks)
print("Vector index:", len(vindex.ids), "chunks, dim =", vindex.matrix.shape[1])
# Out:
# Embedding:   0%|          | 0/211 [00:00<?, ?it/s]
# Vector index: 211 chunks, dim = 768

# %% [markdown]
# ## Part 6 — GraphRAG Querying (multi-hop)
#
# The GraphRAG retrieval pipeline:
#
# 1. **Entity linking** — find graph nodes mentioned in the question.
# 2. **Multi-hop traversal** — expand a k-hop subgraph around those seeds.
# 3. **Verbalize** the subgraph edges into facts + pull the **provenance chunks**.
# 4. **Answer** from graph facts *and* supporting text.

# %%
def link_entities(query, max_seeds=5):
    ql = query.lower()
    seeds = [n for n in G.nodes if n.lower() in ql]
    if not seeds:                      # fuzzy fallback on query tokens
        names = list(G.nodes)
        for token in re.findall(r"[A-Za-z][A-Za-z0-9&.\- ]{2,}", query):
            m = difflib.get_close_matches(token.strip().lower(),
                                          [x.lower() for x in names], n=1, cutoff=0.8)
            if m:
                seeds += [x for x in names if x.lower() == m[0] and x not in seeds]
    return sorted(set(seeds), key=lambda n: G.degree(n), reverse=True)[:max_seeds]

def k_hop_subgraph(seeds, hops=2, max_nodes=40):
    nodes, frontier = set(seeds), set(seeds)
    for _ in range(hops):
        nxt = set()
        for n in frontier:
            nxt.update(G.successors(n)); nxt.update(G.predecessors(n))
        nodes.update(nxt); frontier = nxt
        if len(nodes) >= max_nodes:
            break
    return G.subgraph(list(nodes)[:max_nodes])

def verbalize(sg):
    lines = {f"({u}) -[{d.get('relation','related_to')}]-> ({v})"
             for u, v, d in sg.edges(data=True)}
    return "\n".join(sorted(lines))

def gather_chunks(sg, limit=6):
    cids, texts = [], []
    for n in sg.nodes:
        for cid in entity_chunks.get(n, []):
            if cid not in cids:
                cids.append(cid)
    by_id = {c["chunk_id"]: c for c in chunks}
    for cid in cids[:limit]:
        if cid in by_id:
            texts.append(f"[{cid}] " + by_id[cid]["text"][:600])
    return texts

def graphrag_answer(query, hops=2):
    seeds = link_entities(query)
    sg = k_hop_subgraph(seeds, hops=hops)
    facts = verbalize(sg)
    evidence = "\n\n".join(gather_chunks(sg))
    prompt = (
        "Answer the question using the KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT below. "
        "Reason across multiple connected facts (multi-hop) when needed. "
        "If the context is insufficient, say so.\n\n"
        "QUESTION: " + query + "\n\n"
        "KNOWLEDGE-GRAPH FACTS:\n" + (facts or "(none found)") + "\n\n"
        "SUPPORTING TEXT:\n" + (evidence or "(none)") + "\n\n"
        "ANSWER:"
    )
    return {"answer": llm_complete(prompt, max_tokens=500), "seeds": seeds,
            "n_facts": len(facts.splitlines()) if facts else 0}

# %%
q = "How does the electric vehicle sector connect to charging infrastructure and government policy?"
res = graphrag_answer(q, hops=2)
print("Seed entities:", res["seeds"])
print("Graph facts used:", res["n_facts"])
print("\nGraphRAG answer:\n", res["answer"])
# Out:
# Seed entities: ['SEC', 'Charging infrastructure', 'infrastructure']
# Graph facts used: 5
#
# GraphRAG answer:
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the connection between the electric vehicle sector, charging infrastructure, and government policy cannot be determined.
#
# The provided information focuses on the business risks, financial performance, and supply chain challenges of specific companies like Polestar and REE. While these companies are part of the electric vehicle sector, the text discusses their reliance on third-party manufacturing partners, potential customs duties, labor costs, and the need for external funding. There are no facts or text that explicitly mention charging infrastructure or government policy.

# %% [markdown]
# ## Part 7 — Flat RAG Baseline
#
# Plain retrieval: embed the query, grab the top-k most similar chunks, answer from those passages only.

# %%
def flat_rag_answer(query, k=4):
    hits = vindex.search(query, k=k)
    context = "\n\n".join(f"[{cid}] " + meta["text"][:700] for cid, _, meta in hits)
    prompt = (
        "Answer the question using ONLY the context passages below. "
        "If the answer is not in the context, say you don't have enough information.\n\n"
        "QUESTION: " + query + "\n\n"
        "CONTEXT:\n" + context + "\n\n"
        "ANSWER:"
    )
    return {"answer": llm_complete(prompt, max_tokens=500),
            "sources": [cid for cid, _, _ in hits]}

fr = flat_rag_answer(q)
print("Sources:", fr["sources"])
print("\nFlat RAG answer:\n", fr["answer"])
# Out:
# Sources: ['doc_18.txt::ch14', 'doc_17.txt::ch5', 'doc_17.txt::ch8', 'doc_1.txt::ch1']
#
# Flat RAG answer:
#  Based on the context provided, the electric vehicle sector connects to charging infrastructure and government policy in the following ways:
#
# *   **Government Policy and Charging Infrastructure:** Governments are involved in supporting the deployment of publicly available charging infrastructure. This support can be through regulations requiring the building of charging stations or through fiscal policies. Government support is seen as necessary to ensure equitable access to charging, at least until there are enough electric vehicles on the road for a charging network to be self-sustaining.
#
# *   **Government Policy and Market Growth:** Regulations, such as those requiring greater electric vehicle model availability and zero-emission vehicle (ZEV) mandates, are essential for market growth. States with ZEV regulations had a significantly higher share of new electric vehicle sales and more available electric models than states without such regulations.
#
# *   **Charging Infrastructure and EV Adoption:** The availability of charging infrastructure is a key factor in the economic case for electrification. While public charging stations are not as ubiquitous as gas stations, a national network is being rapidly established by a combination of manufacturers, automakers, utilities, and government agencies. The ability to charge at residences, workplaces, and public locations provides flexibility for drivers.

# %% [markdown]
# ## Part 8 — Flat RAG vs GraphRAG Comparison
#
# Run the same question set through both pipelines. Look for questions that require *connecting*
# entities across documents — that is where GraphRAG's multi-hop traversal tends to win, while
# Flat RAG is limited to whatever a single similar passage happens to contain.

# %%
questions = [
    "How does the electric vehicle sector connect to charging infrastructure and government policy?",
    "Which companies are mentioned in relation to EV market growth, and how are they connected?",
    "What financial trends or sentiments are associated with renewable energy investments?",
    "How do government incentives relate to EV adoption across regions?",
    "Which companies are the main competitors of Tesla in the US market?",
    "What is the role of lithium-ion batteries in the electric vehicle supply chain?",
    "How does artificial intelligence impact autonomous driving development?",
    "Which tech companies are investing heavily in solid-state battery research?",
    "What are the environmental concerns related to EV battery disposal?",
    "How do supply chain shortages affect EV production timelines?",
    "What partnerships exist between traditional automakers and tech startups?",
    "How does the expansion of charging networks influence consumer EV adoption?",
    "Which government policies in Europe are accelerating the transition to EVs?",
    "What is the connection between smart grid technology and EV charging?",
    "How are tech companies addressing cybersecurity risks in connected vehicles?",
    "What role do raw materials like cobalt and nickel play in the EV market?",
    "How is vehicle-to-grid (V2G) technology being implemented by major automakers?",
    "What are the future predictions for autonomous trucking companies?",
    "How do software updates over-the-air (OTA) change the automotive industry?",
    "Which factors contribute most to the price parity between EVs and gas cars?"
]

rows = []
for ques in tqdm(questions, desc="Comparing"):
    g = graphrag_answer(ques, hops=2)
    f = flat_rag_answer(ques, k=4)
    rows.append({"question": ques,
                 "graph_seeds": ", ".join(g["seeds"]) or "(none)",
                 "graphrag_answer": g["answer"],
                 "flatrag_answer": f["answer"]})

pd.set_option("display.max_colwidth", 350)
comparison = pd.DataFrame(rows)
comparison
# Out:
# Comparing:   0%|          | 0/20 [00:00<?, ?it/s]
#                                                                                           question  \
# 0   How does the electric vehicle sector connect to charging infrastructure and government policy?
# 1       Which companies are mentioned in relation to EV market growth, and how are they connected?
# 2            What financial trends or sentiments are associated with renewable energy investments?
# 3                               How do government incentives relate to EV adoption across regions?
# 4                              Which companies are the main competitors of Tesla in the US market?
# 5                  What is the role of lithium-ion batteries in the electric vehicle supply chain?
# 6                          How does artificial intelligence impact autonomous driving development?
# 7                      Which tech companies are investing heavily in solid-state battery research?
# 8                              What are the environmental concerns related to EV battery disposal?
# 9                                    How do supply chain shortages affect EV production timelines?
# 10                       What partnerships exist between traditional automakers and tech startups?
# 11                     How does the expansion of charging networks influence consumer EV adoption?
# 12                     Which government policies in Europe are accelerating the transition to EVs?
# 13                           What is the connection between smart grid technology and EV charging?
# 14                    How are tech companies addressing cybersecurity risks in connected vehicles?
# 15                        What role do raw materials like cobalt and nickel play in the EV market?
# 16                  How is vehicle-to-grid (V2G) technology being implemented by major automakers?
# 17                              What are the future predictions for autonomous trucking companies?
# 18                      How do software updates over-the-air (OTA) change the automotive industry?
# 19                     Which factors contribute most to the price parity between EVs and gas cars?
#
#                                                 graph_seeds  \
# 0              SEC, Charging infrastructure, infrastructure
# 1                       EV market, market growth, companies
# 2                                       investments, energy
# 3                                   incentives, EV adoption
# 4              Tesla, competitors, US market, US, companies
# 5   Batteries, supply chain, lithium-ion batteries, lithium
# 6                  US, development, artificial intelligence
# 7                                                 companies
# 8                                               environment
# 9                                  supply chain, production
# 10                       partners, Automakers, partnerships
# 11                                              EV adoption
# 12                                              EVs, Europe
# 13                                               technology
# 14                             vehicles, SEC, SK, companies
# 15      EV market, materials, cobalt, nickel, raw materials
# 16                                   technology, Automakers
# 17                                            US, companies
# 18            Automotive, automotive industry, US, software
# 19                                                EVs, Cars
#
#                                                                                                                                                                                                                                                                                                                                                   graphrag_answer  \
# 0   Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the connection between the electric vehicle sector, charging infrastructure, and government policy cannot be determined.\n\nThe provided information focuses on the business risks and financial performance of specific companies like Polestar and REE. These risks include:\n*   **Sup...
# 1   Based on the provided knowledge-graph facts and supporting text, here are the companies mentioned in relation to EV market growth and their connections:\n\n**Companies Mentioned:**\n\n*   **Cox Automotive:** An automotive data and analysis firm that provides insights on the EV market.\n*   **Tesla:** An EV manufacturer whose sales are noted as ...
# 2   Based on the provided knowledge-graph facts and supporting text, the financial trends and sentiments associated with renewable energy investments are mixed, reflecting a maturing and consolidating market with both significant capital commitments and growing investor caution.\n\nHere is a breakdown of the key trends and sentiments:\n\n**1. Signi...
# 3   Based on the knowledge-graph facts and supporting text, government incentives are a key driver of EV adoption, and their effectiveness is demonstrated across different regions, particularly in the United States.\n\nHere is a multi-hop reasoning connecting the facts:\n\n1.  **Incentives Drive Sales:** The knowledge graph explicitly states that `...
# 4   Based on the knowledge-graph facts and supporting text, the main competitors of Tesla in the US market are:\n\n*   **Ford:** The facts state that Ford "expects competition from Tesla" and "competes with BYD," which is a major competitor that has "overtaken Tesla." The supporting text also lists Ford as one of nine manufacturers that recorded ov...
# 5   Based on the provided knowledge-graph facts and supporting text, the role of lithium-ion batteries in the electric vehicle supply chain is that they are a critical component whose supply can be disrupted or face shortages, which in turn affects the manufacturer's operations, costs, and profitability.\n\nHere is the reasoning, connecting multipl...
# 6   Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, it is impossible to determine how artificial intelligence impacts autonomous driving development.\n\nThe provided context is insufficient for the following reasons:\n\n1.  **No Mention of AI or Autonomous Driving:** The SUPPORTING TEXT discusses financial performance, risks, and m...
# 7   Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information about which tech companies are investing heavily in solid-state battery research. The text discusses Polestar, a vehicle manufacturer, and its risks related to FDI regimes in Sweden and its own financial resources, but it does not mention any tech companies...
# 8   Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information available regarding the environmental concerns related to EV battery disposal. The documents focus on the growth, benefits, market status, and financial performance of electric vehicles, but do not mention battery disposal or its associated environmental is...
# 9   Based on the provided knowledge-graph facts and supporting text, here is the answer:\n\nSupply chain shortages can negatively affect EV production timelines by disrupting the supply of critical materials and causing delays in the operationalization of new production facilities.\n\nThe supporting text provides the following specific details:\n\n...
# 10  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the context is insufficient to answer the question.\n\nThe SUPPORTING TEXT mentions that Polestar, an electric vehicle brand, has "strategic partners" and "manufacturing partners." However, it does not name any of these partners or specify if they are tech startups. The text also ...
# 11  Based on the provided knowledge-graph facts and supporting text, the expansion of charging networks is not directly discussed. Therefore, the context is insufficient to answer the question.\n\nThe provided information focuses on other factors that influence EV adoption, such as:\n*   **CO2 standards** and **vehicle efficiency standards**, which...
# 12  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is insufficient information to answer the question.\n\nThe SUPPORTING TEXT discusses the financial performance and business risks of companies like Polestar and Mercedes-Benz Mobility, including their reliance on manufacturing partners, the impact of customs duties, and the ...
# 13  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information to establish a connection between smart grid technology and EV charging.\n\nThe provided text discusses the financial performance, manufacturing, and market dynamics of electric vehicle companies like Polestar and Nio, as well as the broader EV market in th...
# 14  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information available to answer the question. The provided facts and text focus on topics such as electric vehicle funding, battery manufacturing, and financial performance, but they do not contain any details about cybersecurity risks in connected vehicles or how tech...
# 15  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the role of raw materials like cobalt and nickel in the EV market cannot be determined.\n\nThe SUPPORTING TEXT mentions "lithium-ion cells or semiconductors" as materials that, if there is a "disruption of supply or shortage," could negatively impact Polestar. However, cobalt and ...
# 16        Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information about how vehicle-to-grid (V2G) technology is being implemented by major automakers. The documents focus on financial performance, risks, and market dynamics for companies like Polestar and the broader EV industry, but they do not mention V2G technology.
# 17  Based on the provided knowledge-graph facts and supporting text, there is no information to answer the question about future predictions for autonomous trucking companies. The text focuses on NVIDIA's business, its AI platforms (like Blackwell), and the expansion of generative AI into various sectors like automotive and healthcare, but it does ...
# 18  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the context is insufficient to answer the question.\n\nThe question asks how software updates over-the-air (OTA) change the automotive industry. However, the provided documents contain only financial statements, revenue figures, and risk disclosures for specific companies like ZEE...
# 19  Based on the provided text, the factors that contribute most to the price parity between EVs and gas cars are:\n\n*   **Initial costs being offset by various incentives:** The text states that "initial costs can be offset by fuel cost savings, federal tax credits, and state and utility incentives." This directly addresses how the higher upfront...
#
#                                                                                                                                                                                                                                                                                                                                                    flatrag_answer
# 0   Based on the context provided, here is how the electric vehicle sector connects to charging infrastructure and government policy:\n\n**Connection to Charging Infrastructure:**\n\n*   **Availability and Cost:** The availability of charging infrastructure is a key factor in the economic case for electric vehicles (EVs). Price signals and charging...
# 1   Based on the context, the following companies are mentioned in relation to EV market growth:\n\n*   **Tesla:** Its stock performance is discussed, noting a 15% average drop in 2023 compared to 2021-2022. It is also credited with driving the boom in market capitalization for pure play EV makers and is mentioned as a source of future competition....
# 2   Based on the context provided, the financial trends and sentiments associated with renewable energy investments are:\n\n*   **Electric vehicle companies perform well in financial markets**, but there is concern about **volatility and competition**.\n*   **Global VC investments in clean energy start-ups fell considerably in 2023** relative to 20...
# 3   Government incentives, offered by states, cities, and utilities in various forms such as purchase incentives, HOV access, toll reduction, and free parking, are linked to greater electric vehicle adoption. Metropolitan areas with high EV uptake had a strong mix of these promotion actions. Additionally, states with zero-emission vehicle (ZEV) reg...
# 4   Based on the context, the main competitors of Tesla in the US market are:\n\n*   **Hyundai-Kia**, which accounted for 8% of US electric car sales in 2023, second only to Tesla.\n*   **European carmakers** (led by Stellantis), which accounted for 25% of US electric car sales.\n*   **Other US carmakers** (like GM and Ford), which accounted for 15...
# 5   Lithium-ion batteries account for almost the entire EV battery market. Most common lithium-ion battery chemistries rely on the critical minerals lithium, cobalt, and nickel. However, lithium iron phosphate (LFP) batteries, a type of lithium-ion battery, do not use nickel or cobalt. The supply chain for EVs requires a wide range of raw materials...
# 6                                                                                                                                                                                       Based on the context provided, artificial intelligence impacts autonomous driving development by creating a multibillion-dollar vertical market for automotive customers.
# 7                                                                                                                                                                                                                                                                                                                                I don't have enough information.
# 8                                                                                                                                                                                                                                                                                                                                I don't have enough information.
# 9   Supply chain shortages can affect EV production timelines by creating potential supply bottlenecks. This is particularly critical for the extraction and processing of raw materials, which have long lead times. The context also states that a company's ability to maintain relationships with existing suppliers and create relationships with new sup...
# 10  Based on the context, the following partnerships exist between traditional automakers and tech startups:\n\n*   **Polestar and Xingji Meizu:** Polestar has formed a joint venture with the tech company Xingji Meizu. The partnership aims to develop Xingji Meizu's Flyme Auto technology platform into an operating system for Polestar cars sold in Ch...
# 11  The expansion of charging networks influences consumer EV adoption by making electric vehicles more cost-competitive and by providing greater convenience and accessibility, similar to refuelling conventional vehicles. Analysis shows that electric vehicle growth is linked to greater availability of public and workplace charging. For example, the...
# 12  Based on the context, the following government policies are accelerating the transition to EVs:\n\n*   **Feebate programmes:** Budget-neutral programmes that tax inefficient ICE vehicles to finance subsidies for low-emission or EV purchases.\n*   **Stringent vehicle efficiency and/or CO2 standards:** These standards have promoted EV adoption in...
# 13                                                                                                                                                                                                                                     Based on the context provided, there is no information about the connection between smart grid technology and EV charging.
# 14                                                                                                                                                                                                                                                                                                                               I don't have enough information.
# 15  Raw materials like cobalt and nickel are critical for the extraction and processing of battery metals. They are essential inputs for electrifying road transport, and their supply is a key focus for governments, investors, and carmakers to secure and avoid potential bottlenecks. Investors are actively seeking opportunities in the mining and proc...
# 16                                                                                                                                                                                                                                                                                                                               I don't have enough information.
# 17  Based on the context, the future predictions for autonomous trucking companies are:\n\n*   **REE** anticipates multiple body designs of full vehicle prototypes will be available for its pipeline customers to validate on private roads in the U.S. and Europe in mid-2022, with first orders expected towards the end of the year.\n*   **REE** also ex...
# 18                                                                                                                                                                                                                                                                                                                               I don't have enough information.
# 19  Based on the context, the following factors contribute to the price parity between EVs and gas cars:\n\n*   **Lower prices:** The context explicitly states that "lower prices have supported EV sales volume in the U.S." and notes a decrease in the average transaction price for new EVs.\n*   **Federal tax credits:** The context mentions "federal ...

# %%
# Read the full answers side by side
for r in rows:
    print("=" * 90)
    print("Q:", r["question"])
    print("seeds:", r["graph_seeds"])
    print("\n-- GraphRAG --\n", r["graphrag_answer"])
    print("\n-- Flat RAG --\n", r["flatrag_answer"], "\n")
# Out:
# ==========================================================================================
# Q: How does the electric vehicle sector connect to charging infrastructure and government policy?
# seeds: SEC, Charging infrastructure, infrastructure
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the connection between the electric vehicle sector, charging infrastructure, and government policy cannot be determined.
#
# The provided information focuses on the business risks and financial performance of specific companies like Polestar and REE. These risks include:
# *   **Supply Chain and Manufacturing:** Reliance on third-party partners, potential production delays, and the impact of customs duties on vehicles manufactured in China and exported to the U.S.
# *   **Financial Performance:** The need for significant external funding, potential shareholder dilution, and the impact of overestimating or underestimating production requirements on profit margins.
# *   **General Business Risks:** Factors such as labor costs, unit sales estimates, and the ability to develop prototypes into marketable products.
#
# However, the text does not contain any facts or statements that explicitly discuss charging infrastructure or government policy in relation to the electric vehicle sector. Therefore, the context is insufficient to answer the question.
#
# -- Flat RAG --
#  Based on the context provided, here is how the electric vehicle sector connects to charging infrastructure and government policy:
#
# **Connection to Charging Infrastructure:**
#
# *   **Availability and Cost:** The availability of charging infrastructure is a key factor in the economic case for electric vehicles (EVs). Price signals and charging infrastructure availability help make EVs more cost-competitive.
# *   **Charging Methods:** EVs and plug-in hybrid electric vehicles (PHEVs) can be charged at residences (including multifamily housing), workplaces, or at public charging stations. PHEVs have added flexibility as they can also refuel with gasoline or diesel.
# *   **Ubiquity and Development:** Public charging stations are not as common as gas stations. A national network of public charging stations is being rapidly established by a combination of entities, including charging equipment manufacturers, automakers, utilities, and government agencies.
# *   **Grid Proximity:** The electric grid is located near most places where people park, which facilitates flexible charging.
#
# **Connection to Government Policy:**
#
# *   **Regulations for Market Growth:** Regulations that require greater electric vehicle model availability are essential for market growth. States with zero-emission vehicle (ZEV) regulations had a significantly higher share of new electric vehicle sales and more available models than states without such regulations.
# *   **Supporting Infrastructure Deployment:** Governments should support the deployment of publicly available charging infrastructure, especially in emerging EV markets, until a network can be sustained by operators. This support can be through regulations requiring the building of stations or through fiscal policies.
# *   **Ensuring Equitable Access:** Government support for charging infrastructure should ensure equitable access for all users.
# *   **Establishing Standards:** In emerging EV markets, governments should establish and tighten fuel economy and emission standards and facilitate electric grid development.
# *   **Promotional Actions:** Metropolitan areas with high electric vehicle uptake have a strong mix of state, city, and utility promotion actions.
#
# ==========================================================================================
# Q: Which companies are mentioned in relation to EV market growth, and how are they connected?
# seeds: EV market, market growth, companies
#
# -- GraphRAG --
#  Based on the provided knowledge-graph facts and supporting text, here are the companies mentioned in relation to EV market growth and their connections:
#
# **Companies Mentioned:**
#
# *   **Cox Automotive:** An automotive data and analysis firm that provides insights on the EV market.
# *   **Tesla:** An EV manufacturer whose sales are noted as influencing overall market dynamics.
# *   **Cadillac, Mercedes, BMW, Audi:** Luxury car manufacturers that experienced significant EV sales growth.
# *   **Chevy:** A brand that manufactures the Bolt, an affordable EV whose sales were temporarily halted.
# *   **Polestar:** An EV manufacturer that may be impacted by Sweden's FDI regime.
# *   **Pilbara Minerals:** A critical mineral company whose lithium stocks are attracting investment.
#
# **Connections:**
#
# 1.  **Cox Automotive** is connected to the **EV market** through analysis and forecasting. Its director, **Stephanie Valdez Streaty**, commented on a sales slowdown and noted that the market is "luxury-driven." This is supported by the strong sales growth of luxury brands like **Cadillac**, **Mercedes**, **BMW**, and **Audi**. Cox also noted that **Tesla**'s sales took a hit, influencing the overall market.
#
# 2.  The **EV market** is connected to **critical mineral companies** (like **Pilbara Minerals**) because the growth of EVs drives demand for battery metals, leading to an increase in the valuation of these companies.
#
# 3.  **Polestar** is connected to **Sweden** through the country's new **FDI regime**, which will affect companies located there. This creates a potential risk for Polestar's operations and supply chain.
#
# -- Flat RAG --
#  Based on the context, the following companies are mentioned in relation to EV market growth:
#
# *   **Tesla:** Its stock performance is discussed, noting a 15% average drop in 2023 compared to 2021-2022. It is also credited with driving the boom in market capitalization for pure play EV makers and is mentioned as a source of future competition.
# *   **BYD:** Its stock performance is noted, with a 15% average fall in 2023 relative to 2022. It is also mentioned as a major Chinese carmaker exporting to Europe and a source of competition for Ford and GM.
# *   **VinFast, Polestar, Canoo, Fisker, Lucid, and Nikola:** These are described as emerging EV players that are missing sales targets and trading low.
# *   **Ford and GM:** These incumbent carmakers are mentioned as being under pressure from Chinese carmakers and BYD in particular. They expressed openness to partnering to compete and noted significant losses on their EV investments.
# *   **Stellantis:** This incumbent carmaker is mentioned as considering the growing importance of Chinese carmakers.
# *   **Major incumbent carmakers:** This group is mentioned as having a flat market capitalization in 2023 compared to 2022, in contrast to the fall in pure play EV makers. They are also noted for using corporate venture capital to fund start-ups.
#
# **Connections:**
#
# *   **Tesla and BYD** are presented as major EV companies whose stock performance is a key indicator of market confidence and growth.
# *   **Emerging players** like VinFast, Polestar, Canoo, Fisker, Lucid, and Nikola are contrasted with the major companies, as they are struggling with sales targets and low stock prices.
# *   **Incumbent carmakers (Ford, GM, Stellantis)** are described as facing pressure and competition from **Chinese carmakers like BYD**, leading them to consider strategic partnerships and adjust their corporate strategies.
# *   **Tesla** is specifically mentioned as a source of future competition for Ford and GM from more affordable models.
# *   **Major incumbent carmakers** are noted for investing in start-ups to develop new technology and maintain a competitive edge.
#
# ==========================================================================================
# Q: What financial trends or sentiments are associated with renewable energy investments?
# seeds: investments, energy
#
# -- GraphRAG --
#  Based on the provided knowledge-graph facts and supporting text, the financial trends and sentiments associated with renewable energy investments are mixed, reflecting a maturing and consolidating market with both significant capital commitments and growing investor caution.
#
# Here is a breakdown of the key trends and sentiments:
#
# **1. Significant Capital Commitments and Growth in Key Areas:**
# *   **Large Investments in Batteries:** There is a strong trend of substantial financial commitment to battery technology. Fact state that `battery investments` have `tripled` to `USD 1 billion` and `battery technology developers` have `attracted` `USD 2.5 billion`. This indicates strong confidence in the core technology of the renewable energy transition.
# *   **Global Spending on Electric Cars:** The supporting text explicitly states, "Global spending on electric cars continues to increase," with "billions in investments already committed as of early 2024."
# *   **Government and Incumbent Investment:** Incumbent carmakers are actively `ramp up` their `investments` and `manufacturing plans`. This is further supported by new industrial policies in major markets like the US and EU that have "supported the expansion plans of major battery and EV manufacturers."
#
# **2. A Cooling of Investor Sentiment and Market Consolidation:**
# *   **Decline in Early-Stage VC:** A significant negative trend is the sharp drop in early-stage funding. The text notes that "early-stage VC for electric carmakers dropped radically in 2023." This is linked to `early-stage investments` `dropping` by `USD 1 billion`.
# *   **Increased Perceived Risk:** As competition intensifies and established players (`incumbents`) increase their own investments, "barriers to entry for new actors get higher, and so do investor perceptions of risk."
# *   **Market Consolidation and Pressure on Profitability:** The market is consolidating, with less profitable companies being pushed out. The text highlights that China's Ministry of Industry is concerned "that too many carmakers remain unprofitable," with Nio recording `net losses` of `USD 3 billion` and Ford reporting `losses` on `EV investments` of up to `USD 5.5 billion` in 2023.
#
# **3. Geopolitical and Economic Headwinds:**
# *   The downturn in VC sentiment is attributed to broader challenges including "geopolitical tensions, supply chain disruptions, high energy prices, and rising inflation
#
# -- Flat RAG --
#  Based on the context provided, the financial trends and sentiments associated with renewable energy investments are:
#
# *   **Electric vehicle companies perform well in financial markets**, but there is concern about **volatility and competition**.
# *   **Global VC investments in clean energy start-ups fell considerably in 2023** relative to 2022, with EVs and batteries being no exception.
# *   There is a trend for major incumbent carmakers to use corporate venture capital to fund start-ups to develop new technology or acquire concepts from new entrants.
# *   The electric car market is described as **dynamic**, with **healthy growth in sales** and improvements in recent years.
#
# ==========================================================================================
# Q: How do government incentives relate to EV adoption across regions?
# seeds: incentives, EV adoption
#
# -- GraphRAG --
#  Based on the knowledge-graph facts and supporting text, government incentives are a key driver of EV adoption, and their effectiveness is demonstrated across different regions, particularly in the United States.
#
# Here is a multi-hop reasoning connecting the facts:
#
# 1.  **Incentives Drive Sales:** The knowledge graph explicitly states that `(EV sales) -[will_be_driven_by]-> (incentives)`. This is supported by the text from doc_2.txt, which calls 2024 "the Year of More... more incentives" and notes that leasing allows buyers to "qualify for the full $7,500 incentive the Inflation Reduction Act offers," linking a specific government policy to consumer purchasing power.
#
# 2.  **Regional Variation in Policy and Success:** The adoption of these incentives is not uniform. The knowledge graph highlights that `(states) -[have]-> (strongest policy supports)` and `(states) -[have]-> (greatest electric vehicle market success)`. This indicates that regional governments play a crucial role in creating an environment conducive to EV adoption.
#
# 3.  **States as Key Players:** The facts show that `(states) -[offer]-> (incentives)` and `(Public charging stations) -[established_by]-> (states)`. This demonstrates that regional governments are not just passive actors but are actively implementing the financial and infrastructural support that drives adoption in their specific areas.
#
# 4.  **Incentives are Part of a Broader Strategy:** Government actions go beyond direct financial incentives. The knowledge graph shows that `(Governments) -[establishes]-> (emission standards)` and `(vehicle efficiency standards) -[promote]-> (EV adoption)`. This means that while incentives are a powerful tool, they are often part of a comprehensive policy package that includes regulations to promote EVs.
#
# In summary, government incentives are a primary driver of EV sales. However, the level of adoption varies significantly by region, with U.S. states that offer the strongest policy supports—including direct incentives and infrastructure development—achieving the greatest market success.
#
# -- Flat RAG --
#  Government incentives, offered by states, cities, and utilities in various forms such as purchase incentives, HOV access, toll reduction, and free parking, are linked to greater electric vehicle adoption. Metropolitan areas with high EV uptake had a strong mix of these promotion actions. Additionally, states with zero-emission vehicle (ZEV) regulations, which mandate greater EV model availability, had a higher combined new electric vehicle share (5%) compared to states without such regulations (1.3%). The analysis also notes that as the EV market matures, reliance on direct subsidies must decrease, and budget-neutral "feebate" programs can be a useful transition tool.
#
# ==========================================================================================
# Q: Which companies are the main competitors of Tesla in the US market?
# seeds: Tesla, competitors, US market, US, companies
#
# -- GraphRAG --
#  Based on the knowledge-graph facts and supporting text, the main competitors of Tesla in the US market are:
#
# *   **Ford:** The facts state that Ford "expects competition from Tesla" and "competes with BYD," which is a major competitor that has "overtaken Tesla." The supporting text also lists Ford as one of nine manufacturers that recorded over 50% year-over-year growth in EV sales in Q1 2024, indicating significant competition in the US market.
#
# *   **Polestar:** The facts show that Polestar "operates in the US market," "competes with competitors," and "aims to capture market share." The supporting text mentions that Polestar's competitors (which would include Tesla) have recently cut prices, and Polestar may be forced to do the same, indicating direct competition.
#
# *   **BYD:** While BYD is a major global competitor that has "overtaken Tesla" and "accounts for 35% of all electric car sales," the knowledge graph does not explicitly state it operates in the US. However, the supporting text mentions that Ford, a direct US competitor, "competes with BYD," and BYD's status as a global leader makes it a significant indirect or potential competitor in the US market.
#
# Additionally, the supporting text identifies other companies with strong EV sales growth in the US, suggesting they are also competitors:
#
# *   **BMW, Cadillac, Hyundai, Kia, Lexus, Mercedes, Rivian, and Vinfast** are all listed as manufacturers that recorded more than 50% year-over-year growth in EV sales in Q1 2024, indicating they are active and growing competitors in the US market.
#
# -- Flat RAG --
#  Based on the context, the main competitors of Tesla in the US market are:
#
# *   **Hyundai-Kia**, which accounted for 8% of US electric car sales in 2023, second only to Tesla.
# *   **European carmakers** (led by Stellantis), which accounted for 25% of US electric car sales.
# *   **Other US carmakers** (like GM and Ford), which accounted for 15% of electric car sales.
#
# ==========================================================================================
# Q: What is the role of lithium-ion batteries in the electric vehicle supply chain?
# seeds: Batteries, supply chain, lithium-ion batteries, lithium
#
# -- GraphRAG --
#  Based on the provided knowledge-graph facts and supporting text, the role of lithium-ion batteries in the electric vehicle supply chain is that they are a critical component whose supply can be disrupted or face shortages, which in turn affects the manufacturer's operations, costs, and profitability.
#
# Here is the reasoning, connecting multiple facts from the text:
#
# 1.  **Lithium-ion batteries are a key material:** The text explicitly identifies "lithium-ion cells" as a specific material that is crucial for production.
# 2.  **Supply chain disruption is a risk:** The text lists "disruption of supply or shortage of materials, in particular for lithium-ion cells or semiconductors" as a factor that could negatively impact Polestar.
# 3.  **Impact on the business:** This risk of a shortage is directly linked to the company's financial performance. A disruption in the supply of lithium-ion cells is mentioned alongside other factors that affect "expenses, profitability, gross margin, cash flow, and cash reserves."
#
# Therefore, the role of lithium-ion batteries is to be a critical input whose reliable supply is essential for maintaining production schedules, controlling costs, and achieving the financial performance necessary for the company to become profitable.
#
# -- Flat RAG --
#  Lithium-ion batteries account for almost the entire EV battery market. Most common lithium-ion battery chemistries rely on the critical minerals lithium, cobalt, and nickel. However, lithium iron phosphate (LFP) batteries, a type of lithium-ion battery, do not use nickel or cobalt. The supply chain for EVs requires a wide range of raw materials, and the extraction and processing of battery metals is particularly critical.
#
# ==========================================================================================
# Q: How does artificial intelligence impact autonomous driving development?
# seeds: US, development, artificial intelligence
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, it is impossible to determine how artificial intelligence impacts autonomous driving development.
#
# The provided context is insufficient for the following reasons:
#
# 1.  **No Mention of AI or Autonomous Driving:** The SUPPORTING TEXT discusses financial performance, risks, and market trends for electric vehicle companies like Polestar and the broader Chinese EV market. It mentions topics such as sales figures, supply chain issues, labor costs, and profitability, but it does not contain any information about artificial intelligence or autonomous driving technology.
# 2.  **Irrelevant Knowledge-Graph Facts:** The KNOWLEDGE-GRAPH FACTS state that "forward-looking statements" relate to "financial performance." While this is a valid business concept, it does not connect to the topic of artificial intelligence's role in autonomous driving.
#
# Therefore, the context provided does not contain the necessary information to answer the question.
#
# -- Flat RAG --
#  Based on the context provided, artificial intelligence impacts autonomous driving development by creating a multibillion-dollar vertical market for automotive customers.
#
# ==========================================================================================
# Q: Which tech companies are investing heavily in solid-state battery research?
# seeds: companies
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information about which tech companies are investing heavily in solid-state battery research. The text discusses Polestar, a vehicle manufacturer, and its risks related to FDI regimes in Sweden and its own financial resources, but it does not mention any tech companies or solid-state battery research.
#
# -- Flat RAG --
#  I don't have enough information.
#
# ==========================================================================================
# Q: What are the environmental concerns related to EV battery disposal?
# seeds: environment
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information available regarding the environmental concerns related to EV battery disposal. The documents focus on the growth, benefits, market status, and financial performance of electric vehicles, but do not mention battery disposal or its associated environmental issues.
#
# -- Flat RAG --
#  I don't have enough information.
#
# ==========================================================================================
# Q: How do supply chain shortages affect EV production timelines?
# seeds: supply chain, production
#
# -- GraphRAG --
#  Based on the provided knowledge-graph facts and supporting text, here is the answer:
#
# Supply chain shortages can negatively affect EV production timelines by disrupting the supply of critical materials and causing delays in the operationalization of new production facilities.
#
# The supporting text provides the following specific details:
#
# 1.  **Disruption of Supply and Shortage of Materials:** The text explicitly states that "disruption of supply or shortage of materials, in particular for lithium-ion cells or semiconductors," is a risk factor for Polestar. A shortage of these essential components would directly halt or slow down production lines, thereby extending production timelines.
#
# 2.  **Delays in New Production Facilities:** Polestar's production depends on its "strategic partners to ensure that new production facilities are operational in the expected timeframe." Any delays in these partners' ability to get new facilities up and running would, in turn, delay Polestar's own production schedules. The text also mentions the risk of "delays in production in the newest facilities that produce Polestar vehicles," which would require continued exports from China and could lead to higher costs.
#
# 3.  **Overestimation of Requirements:** If Polestar overestimates its production needs, it may reserve excess manufacturing capacity from its partners. This situation could lead to "indirect[ly] increase Polestar’s costs" and negatively impact its gross margins. While this fact primarily relates to financial performance, it shows a complex dependency on partners' capacity, which, if mismanaged, could lead to inefficient production scheduling and timelines.
#
# -- Flat RAG --
#  Supply chain shortages can affect EV production timelines by creating potential supply bottlenecks. This is particularly critical for the extraction and processing of raw materials, which have long lead times. The context also states that a company's ability to maintain relationships with existing suppliers and create relationships with new suppliers is a factor that can affect production.
#
# ==========================================================================================
# Q: What partnerships exist between traditional automakers and tech startups?
# seeds: partners, Automakers, partnerships
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the context is insufficient to answer the question.
#
# The SUPPORTING TEXT mentions that Polestar, an electric vehicle brand, has "strategic partners" and "manufacturing partners." However, it does not name any of these partners or specify if they are tech startups. The text also refers to a reliance on "third-party partner manufacturing," but again, no specific partners are identified.
#
# Therefore, while the text confirms that partnerships exist, it does not provide the specific examples of partnerships between traditional automakers and tech startups that the question asks for.
#
# -- Flat RAG --
#  Based on the context, the following partnerships exist between traditional automakers and tech startups:
#
# *   **Polestar and Xingji Meizu:** Polestar has formed a joint venture with the tech company Xingji Meizu. The partnership aims to develop Xingji Meizu's Flyme Auto technology platform into an operating system for Polestar cars sold in China. This collaboration combines Polestar's design and performance capabilities with Xingji Meizu's software and consumer electronics hardware development expertise.
# *   **Ford and GM:** These traditional automakers have expressed openness to partnering with each other to compete against Chinese carmakers like BYD.
# *   **Major incumbent carmakers:** The text states that traditional carmakers use corporate venture capital (VC) to fund startups to develop new technology or acquire concepts from new entrants.
#
# ==========================================================================================
# Q: How does the expansion of charging networks influence consumer EV adoption?
# seeds: EV adoption
#
# -- GraphRAG --
#  Based on the provided knowledge-graph facts and supporting text, the expansion of charging networks is not directly discussed. Therefore, the context is insufficient to answer the question.
#
# The provided information focuses on other factors that influence EV adoption, such as:
# *   **CO2 standards** and **vehicle efficiency standards**, which are stated to "promote EV adoption."
# *   **"Feebate" programmes** and **subsidies**, which are mentioned as transition policy tools.
# *   **Competitive prices** and a **maturing market**, which are expected to reduce reliance on subsidies.
#
# -- Flat RAG --
#  The expansion of charging networks influences consumer EV adoption by making electric vehicles more cost-competitive and by providing greater convenience and accessibility, similar to refuelling conventional vehicles. Analysis shows that electric vehicle growth is linked to greater availability of public and workplace charging. For example, the ten most populous metropolitan areas in the U.S. with the highest EV uptake had significantly more public and workplace chargers per million population than other areas.
#
# ==========================================================================================
# Q: Which government policies in Europe are accelerating the transition to EVs?
# seeds: EVs, Europe
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is insufficient information to answer the question.
#
# The SUPPORTING TEXT discusses the financial performance and business risks of companies like Polestar and Mercedes-Benz Mobility, including their reliance on manufacturing partners, the impact of customs duties, and the financial challenges of establishing charging activities. However, it does not mention any specific government policies in Europe that are accelerating the transition to electric vehicles (EVs). The text provides no details on regulations, subsidies, or incentives implemented by European governments.
#
# -- Flat RAG --
#  Based on the context, the following government policies are accelerating the transition to EVs:
#
# *   **Feebate programmes:** Budget-neutral programmes that tax inefficient ICE vehicles to finance subsidies for low-emission or EV purchases.
# *   **Stringent vehicle efficiency and/or CO2 standards:** These standards have promoted EV adoption in leading markets.
# *   **Establishing and tightening fuel economy and emission standards:** This is recommended for emerging EV markets.
# *   **Supporting the deployment of publicly available charging infrastructure:** This can be done through regulations requiring the building of charging stations or through fiscal policies and support.
# *   **Requiring the building out of charging stations:** This is mentioned as a way to ensure equitable access to charging.
#
# ==========================================================================================
# Q: What is the connection between smart grid technology and EV charging?
# seeds: technology
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information to establish a connection between smart grid technology and EV charging.
#
# The provided text discusses the financial performance, manufacturing, and market dynamics of electric vehicle companies like Polestar and Nio, as well as the broader EV market in the U.S. and China. However, it does not contain any facts or details related to smart grid technology, which would involve the integration of EV charging with the power grid for efficient energy distribution and management.
#
# -- Flat RAG --
#  Based on the context provided, there is no information about the connection between smart grid technology and EV charging.
#
# ==========================================================================================
# Q: How are tech companies addressing cybersecurity risks in connected vehicles?
# seeds: vehicles, SEC, SK, companies
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information available to answer the question. The provided facts and text focus on topics such as electric vehicle funding, battery manufacturing, and financial performance, but they do not contain any details about cybersecurity risks in connected vehicles or how tech companies are addressing them.
#
# -- Flat RAG --
#  I don't have enough information.
#
# ==========================================================================================
# Q: What role do raw materials like cobalt and nickel play in the EV market?
# seeds: EV market, materials, cobalt, nickel, raw materials
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the role of raw materials like cobalt and nickel in the EV market cannot be determined.
#
# The SUPPORTING TEXT mentions "lithium-ion cells or semiconductors" as materials that, if there is a "disruption of supply or shortage," could negatively impact Polestar. However, cobalt and nickel are not mentioned at all. The text does not provide any information about the specific role, function, or importance of cobalt and nickel in the EV market.
#
# -- Flat RAG --
#  Raw materials like cobalt and nickel are critical for the extraction and processing of battery metals. They are essential inputs for electrifying road transport, and their supply is a key focus for governments, investors, and carmakers to secure and avoid potential bottlenecks. Investors are actively seeking opportunities in the mining and processing of these critical minerals, and companies are forming partnerships to secure their supply.
#
# ==========================================================================================
# Q: How is vehicle-to-grid (V2G) technology being implemented by major automakers?
# seeds: technology, Automakers
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, there is no information about how vehicle-to-grid (V2G) technology is being implemented by major automakers. The documents focus on financial performance, risks, and market dynamics for companies like Polestar and the broader EV industry, but they do not mention V2G technology.
#
# -- Flat RAG --
#  I don't have enough information.
#
# ==========================================================================================
# Q: What are the future predictions for autonomous trucking companies?
# seeds: US, companies
#
# -- GraphRAG --
#  Based on the provided knowledge-graph facts and supporting text, there is no information to answer the question about future predictions for autonomous trucking companies. The text focuses on NVIDIA's business, its AI platforms (like Blackwell), and the expansion of generative AI into various sectors like automotive and healthcare, but it does not mention autonomous trucking or provide any specific predictions for that industry.
#
# -- Flat RAG --
#  Based on the context, the future predictions for autonomous trucking companies are:
#
# *   **REE** anticipates multiple body designs of full vehicle prototypes will be available for its pipeline customers to validate on private roads in the U.S. and Europe in mid-2022, with first orders expected towards the end of the year.
# *   **REE** also expects to establish a global service network with Data-as-a-Service capabilities by the end of 2022.
# *   **REE** signed a joint development agreement with a leading global commercial vehicle OEM to jointly develop a Class 4 electrified P7 platform for commercial trucks, school buses, walk-in-vans, and recreational vehicles.
#
# ==========================================================================================
# Q: How do software updates over-the-air (OTA) change the automotive industry?
# seeds: Automotive, automotive industry, US, software
#
# -- GraphRAG --
#  Based on the provided KNOWLEDGE-GRAPH FACTS and SUPPORTING TEXT, the context is insufficient to answer the question.
#
# The question asks how software updates over-the-air (OTA) change the automotive industry. However, the provided documents contain only financial statements, revenue figures, and risk disclosures for specific companies like ZEEKR and Polestar. There is no mention of software updates, over-the-air (OTA) technology, or any discussion of how such technology impacts the industry. The knowledge-graph fact about "forward-looking statements" and "financial performance" is not relevant to the specific topic of OTA updates.
#
# -- Flat RAG --
#  I don't have enough information.
#
# ==========================================================================================
# Q: Which factors contribute most to the price parity between EVs and gas cars?
# seeds: EVs, Cars
#
# -- GraphRAG --
#  Based on the provided text, the factors that contribute most to the price parity between EVs and gas cars are:
#
# *   **Initial costs being offset by various incentives:** The text states that "initial costs can be offset by fuel cost savings, federal tax credits, and state and utility incentives." This directly addresses how the higher upfront price of an EV can be balanced out.
# *   **Fuel cost savings:** The text mentions that fuel cost savings can help offset the initial cost of an EV, contributing to overall affordability.
# *   **Federal tax credits:** Specific programs like the "federal Clean Vehicle Tax Credits" are available to consumers, fleets, and businesses for purchasing new, used, and commercial clean vehicles, including EVs.
# *   **State and utility incentives:** In addition to federal credits, "some states and electric utilities also offer incentives" that further reduce the cost of purchasing an EV.
#
# -- Flat RAG --
#  Based on the context, the following factors contribute to the price parity between EVs and gas cars:
#
# *   **Lower prices:** The context explicitly states that "lower prices have supported EV sales volume in the U.S." and notes a decrease in the average transaction price for new EVs.
# *   **Federal tax credits:** The context mentions "federal tax credits" as a factor that can "offset initial costs."
# *   **State and utility incentives:** The context notes that "some states and electric utilities also offer incentives" that can help offset initial costs.
# *   **Fuel cost savings:** The context states that initial costs can be offset by "fuel cost savings," and it provides an example of a hybrid vehicle achieving better fuel economy than a conventional one.
# *   **Fees and rebates:** The context mentions "budget-neutral 'feebate' programmes – which tax inefficient ICE vehicles to finance subsidies for low-emission or EV purchases" as a transition policy tool.

# %% [markdown]
# ## Part 8.5 — Cost Analysis (Token Usage & Time)
#
# This section estimates the token usage and tracks the time taken for graph construction.

# %%
# Approximate token usage calculation for Graph Construction
# Assuming ~1.3 tokens per word for English text
total_words = sum(len(ch["text"].split()) for ch in chunks)
estimated_tokens = int(total_words * 1.3)

print("=== Graph Construction Cost Analysis ===")
print(f"Total chunks processed: {len(chunks)}")
print(f"Estimated total tokens processed: {estimated_tokens:,} tokens")
print(f"Estimated cost (if using OpenAI GPT-4o-mini at $0.15/1M input tokens): ${((estimated_tokens / 1000000) * 0.15):.4f}")
print("Note: Time taken can be seen in the tqdm progress bars during extraction.")
# Out:
# === Graph Construction Cost Analysis ===
# Total chunks processed: 211
# Estimated total tokens processed: 47,277 tokens
# Estimated cost (if using OpenAI GPT-4o-mini at $0.15/1M input tokens): $0.0071
# Note: Time taken can be seen in the tqdm progress bars during extraction.

# %% [markdown]
# ## Part 9 — Conclusion & Takeaways
#
# **What we built:** a complete GraphRAG pipeline — extraction (LangExtract or prompt) → dedup →
# knowledge graph → multi-hop retrieval → grounded answer — plus a Flat RAG baseline for comparison,
# all behind provider/backend switches (Ollama/OpenAI, NetworkX/Neo4j, LangExtract/prompt).
#
# **When GraphRAG wins:** questions that require *connecting* facts spread across documents
# ("how is A related to C through B"). The graph encodes those relationships explicitly, so traversal
# surfaces them even when no single passage states the connection.
#
# **When Flat RAG is enough:** direct lookups where the answer sits inside one passage — it is simpler
# and cheaper (no extraction step).
#
# **Knobs to explore:**
# - Raise `MAX_DOCS` toward the full corpus and re-run.
# - Switch `EXTRACTION_BACKEND` between `langextract` (few-shot, grounded) and `prompt` (baseline).
# - Increase `hops` (2 → 3) for deeper multi-hop reasoning.
# - Tighten the extraction prompt / dedup `cutoff` for a cleaner graph.
# - Switch `LLM_PROVIDER` to `openai` for higher-quality extraction and answers.
#
# **Interview-style questions to check understanding:**
# 1. Why does poor entity deduplication degrade GraphRAG more than Flat RAG?
# 2. How does multi-hop traversal answer questions that vector similarity alone cannot?
# 3. What are the cost/latency trade-offs of the extraction step versus plain embedding?
# 4. How would you evaluate GraphRAG vs Flat RAG quantitatively (e.g., an LLM judge or a labelled QA set)?
